# %% [markdown]
# <a href="https://colab.research.google.com/github/franfram/Transformers-nlp/blob/main/vocab_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# https://stackoverflow.com/questions/51666374/how-to-remove-strings-present-in-a-list-from-a-column-in-pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 7.7 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 44.0 MB/s
# ...
#      |████████████████████████████████| 163 kB 69.5 MB/s
# ...

# %%
from transformers import AutoTokenizer

# Load tokenizer
checkpoint = "CenIA/distillbert-base-spanish-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

vocab = tokenizer.get_vocab()
list(vocab.keys())[:100]
# Out:
# Downloading:   0%|          | 0.00/361 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/248k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/486k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ['incorpor',
#  'inn',
#  'curr',
#  'desactiv',
#  'solu',
#  'susto',
#  'establezcan',
#  'enamoré',
#  'enseñaste',
#  'ahora',
#  '##ridas',
#  'premier',
#  'desempeñar',
#  'fallos',
#  'problemática',
#  'confió',
#  'asombr',
#  'chofer',
#  'implicados',
#  'jessie',
#  'respecta',
#  '##raba',
#  'náu',
#  '##phy',
#  'altar',
#  'transbordador',
#  'facción',
#  'granito',
#  '##agésimo',
#  'energy',
#  'efectú',
#  '[unused604]',
#  '##o',
#  'rastrear',
#  'ferroviario',
#  '[unused617]',
#  'libanes',
#  'jaguar',
#  '##sen',
#  'produce',
#  '##icionado',
#  'fuegos',
#  'urgente',
#  'cohetes',
#  '##ega',
#  '[unused77]',
#  '##érica',
#  'gafas',
#  '##jaron',
#  'entradas',
#  'opuso',
#  '##tiende',
#  'menudo',
#  '##odin',
# ...

# %%
"importado" in vocab.keys()

test = list(vocab.keys())
test



#hacer algo como
bad_words_ids = list(vocab.keys())

words_to_delete = ['forzado', 'vendieron', 'verticales']

def create_bad_words_ids(bad_words_ids, words_to_delete):
  for pictogram in range(len(words_to_delete)):
    if words_to_delete[pictogram] in bad_words_ids:
      bad_words_ids.remove(words_to_delete[pictogram])
  return bad_words_ids

bad_words_ids = create_bad_words_ids(bad_words_ids=bad_words_ids, words_to_delete=words_to_delete)
print(bad_words_ids)



# for pictogram in range(len(words_to_delete)):
#   if words_to_delete[pictogram] in constrained_vocab:
#      constrained_vocab.remove('denominados')

# "denominados" in constrained_vocab

#  for pictogram in range(len(constrained_vocab)):  
#    if pictogram in list(vocab.keys())
#     pop that pictogram[pict] from contrained_vocab


# bad_words_ids = constrained_vocab

# constrained_vocab
# Out:
# ['incorpor', 'inn', 'curr', 'desactiv', 'solu', 'susto', 'establezcan', 'enamoré', 'enseñaste', 'ahora', '##ridas', 'premier', 'desempeñar', 'fallos', 'problemática', 'confió', 'asombr', 'chofer', 'implicados', 'jessie', 'respecta', '##raba', 'náu', '##phy', 'altar', 'transbordador', 'facción', 'granito', '##agésimo', 'energy', 'efectú', '[unused604]', '##o', 'rastrear', 'ferroviario', '[unused617]', 'libanes', 'jaguar', '##sen', 'produce', '##icionado', 'fuegos', 'urgente', 'cohetes', '##ega', '[unused77]', '##érica', 'gafas', '##jaron', 'entradas', 'opuso', '##tiende', 'menudo', '##odin', 'superfici', 'húme', 'presentados', 'enfri', 'poetas', 'microfic', 'mes', 'portátiles', 'depu', 'emitida', '##énica', 'v', 'carden', 'arm', 'hubier', '[unused685]', '##idar', '1913', '##ces', 'instructores', 'fractura', 'tortuga', '[unused727]', 'únicos', '##cenas', 'encargo', 'encontrados', 'eter', 'cristiano', 'paseo', 'auda', 'cristóbal', 'concursos', 'deberían', 'alimenticios', 'proyecta', 'vo
# ...

# %%
# https://stackoverflow.com/questions/71650016/how-to-know-if-a-word-belong-to-a-transformer-model
from transformers import RobertaTokenizer
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
vocab = tokenizer.get_vocab()
list(vocab.keys())[:100]
# Out:
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# ['<s>',
#  '<pad>',
#  '</s>',
#  '<unk>',
#  '.',
#  'Ġthe',
#  ',',
#  'Ġto',
#  'Ġand',
#  'Ġof',
#  'Ġa',
#  'Ġin',
#  '-',
#  'Ġfor',
#  'Ġthat',
#  'Ġon',
#  'Ġis',
#  'âĢ',
#  "'s",
#  'Ġwith',
#  'ĠThe',
#  'Ġwas',
#  'Ġ"',
#  'Ġat',
#  'Ġit',
#  'Ġas',
#  'Ġsaid',
#  'Ļ',
#  'Ġbe',
#  's',
#  'Ġby',
#  'Ġfrom',
#  'Ġare',
#  'Ġhave',
#  'Ġhas',
#  ':',
#  'Ġ(',
#  'Ġhe',
#  'ĠI',
#  'Ġhis',
#  'Ġwill',
#  'Ġan',
#  'Ġthis',
#  ')',
#  'ĠâĢ',
#  'Ġnot',
#  'Ŀ',
#  'Ġyou',
#  'ľ',
#  'Ġtheir',
#  'Ġor',
#  'Ġthey',
#  'Ġwe',
#  'Ġbut',
#  'Ġwho',
#  'Ġmore',
#  'Ġhad',
#  'Ġbeen',
#  'Ġwere',
#  'Ġabout',
#  ',"',
#  'Ġwhich',
#  'Ġup',
#  'Ġits',
#  'Ġcan',
#  'Ġone',
#  'Ġout',
#  'Ġalso',
#  'Ġ$',
#  'Ġher',
#  'Ġall',
#  'Ġafter',
#  '."',
#  '/',
#  'Ġwould',
#  "'t",
#  'Ġyear',
#  'Ġwhen',
# ...

# %%
"his" in vocab.keys()
# Out:
# True
